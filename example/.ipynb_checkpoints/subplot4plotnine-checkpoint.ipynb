# %%
import os
import time
import pandas as pd
import patchworklib as pw
import numpy as np
from plotnine import *
from plotnine.data import *
t0 = time.time()
quick = True

# %%
# %%time
if "flights.csv" in os.listdir():
    pass
else:
    os.system("wget https://raw.githubusercontent.com/mwaskom/seaborn-data/master/flights.csv")
flights = pd.read_csv('flights.csv')
months = flights['month'].unique()  # Months ordered January, ..., December
flights['month'] = pd.Categorical(flights['month'], categories=months)
flights.head()
text_color = np.array(['black']*len(flights))
text_color[flights['passengers']<300] = 'white'
g = (ggplot(flights, aes('factor(year)', 'month', fill='passengers'))
 + geom_tile(aes(width=.95, height=.95))
 + geom_text(aes(label='passengers'), size=10, color=text_color)
 + scale_y_discrete(limits=months[::-1])          
 + theme(                                         
     axis_ticks=element_blank(),
     panel_background=element_rect(fill='white'))
)
g1 = pw.load_ggplot(g, figsize=(4,4))
g1.savefig(quick=quick)
# Out:
# CPU times: user 1.59 s, sys: 12.5 ms, total: 1.61 s
# Wall time: 1.62 s

# %%
# %%time
g = (ggplot(mtcars, aes('wt', 'mpg', color='factor(gear)'))
 + geom_point()
 + stat_smooth(method='lm')
 + facet_wrap('~gear'))
g2 = pw.load_ggplot(g, figsize=(4,4))
g2.savefig(quick=quick)
# Out:
# CPU times: user 1.07 s, sys: 450 ms, total: 1.52 s
# Wall time: 600 ms

# %%
# %%time
g12 = (g1|g2)
g12.savefig(quick=quick)
# Out:
# CPU times: user 240 ms, sys: 2.69 ms, total: 243 ms
# Wall time: 242 ms

# %%
# %%time
g12_v = (g1/g2)
g12_v.savefig(quick=quick)
# Out:
# CPU times: user 249 ms, sys: 2.85 ms, total: 251 ms
# Wall time: 250 ms

# %%
# %%time
g12_v = (g1.outline/g2.outline)
g12_v.savefig(quick=quick)
# Out:
# CPU times: user 856 ms, sys: 7.83 ms, total: 864 ms
# Wall time: 864 ms

# %%
# %%time
g = (ggplot(diamonds, aes(x='carat', y=after_stat('ncount'))) 
 + geom_histogram(binwidth=0.5)
 + facet_grid('cut ~ color'))
g3 = pw.load_ggplot(g, figsize=(9,5))
g3.savefig(quick=quick)
# Out:
# CPU times: user 5.11 s, sys: 336 ms, total: 5.45 s
# Wall time: 4.99 s

# %%
# %%time
g = (ggplot(data=diamonds) 
 + geom_bar(mapping=aes(x="cut", fill="clarity"), position="dodge")
 + scale_fill_brewer(palette="Accent", type='qual', direction=1)
 + theme_classic()
 + coord_flip())
g4 = pw.load_ggplot(g, figsize=(3,8))
g4.savefig(quick=quick)
# Out:
# CPU times: user 691 ms, sys: 9.97 ms, total: 701 ms
# Wall time: 705 ms

# %%
# %%time
g12 = (g1|g2)
g12.savefig(quick=quick)
# Out:
# CPU times: user 299 ms, sys: 2.77 ms, total: 302 ms
# Wall time: 302 ms

# %%
# %%time
g123 = (g1|g2)/g3
g123.savefig(quick=quick)
# Out:
# CPU times: user 1.78 s, sys: 10.4 ms, total: 1.79 s
# Wall time: 1.79 s

# %%
# %%time
g1234 = ((g1|g2)/g3)|g4
g1234.savefig("../img/plotnine.png",quick=quick)
# Out:
# CPU times: user 4.66 s, sys: 53.4 ms, total: 4.71 s
# Wall time: 4.73 s

# %%
print(time.time()-t0)
# Out:
# 20.067721843719482
